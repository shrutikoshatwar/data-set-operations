# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutikoshatwar/data-set-operations/blob/main/speacialtask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2238978-b59f-48a5-a87f-b1a1be2a20a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2238978-b59f-48a5-a87f-b1a1be2a20a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = "/content/feature_description.csv"
df=pd.read_csv(filepath)

# %%
df
# Out:
#                            Feature      Type    Units  Stage  \
# 0                  received_snr_db     float       dB  A/B/C
# 1            carrier_frequency_ghz     float      GHz  A/B/C
# 2              elevation_angle_deg     float  degrees  A/B/C
# 3                   slant_range_km     float       km  A/B/C
# 4                        timestamp  datetime      UTC  A/B/C
# 5                          fspl_db     float       dB      A
# 6           gaseous_attenuation_db     float       dB      A
# 7            excess_attenuation_db     float       dB      A
# 8         effective_path_length_km     float       km      A
# 9   specific_attenuation_db_per_km     float    dB/km      A
# 10                  rain_height_km     float       km      A
# 11              snr_roll_mean_5min     float       dB      B
# 12               snr_roll_std_5min     float       dB      B
# 13               snr_roll_max_5min     float       dB      B
# ...

# %%
df.head()
# Out:
#                  Feature      Type    Units  Stage  \
# 0        received_snr_db     float       dB  A/B/C
# 1  carrier_frequency_ghz     float      GHz  A/B/C
# 2    elevation_angle_deg     float  degrees  A/B/C
# 3         slant_range_km     float       km  A/B/C
# 4              timestamp  datetime      UTC  A/B/C
#
#                                          Description
# 0                     Received signal-to-noise ratio
# 1            Carrier frequency of the satellite link
# 2                Ground-to-satellite elevation angle
# 3  Slant range distance from ground station to sa...
# 4                               Simulation timestamp

# %%
df.tail()
# Out:
#           Feature    Type Units Stage  \
# 22          itu_k   float     —     C
# 23      itu_alpha   float     —     C
# 24        station  string     —   B/C
# 25        climate  string     —   B/C
# 26  simulation_id  string     —   B/C
#
#                                       Description
# 22       ITU-R specific attenuation coefficient k
# 23      ITU-R specific attenuation exponent alpha
# 24  Ground station name for cross-site validation
# 25                    Climate type classification
# 26                      Simulation run identifier

# %%
df.shape
# Out:
# (27, 5)

# %%
df.columns
# Out:
# Index(['Feature', 'Type', 'Units', 'Stage', 'Description'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Feature      27 non-null     object
#  1   Type         27 non-null     object
#  2   Units        27 non-null     object
#  3   Stage        27 non-null     object
#  4   Description  27 non-null     object
# dtypes: object(5)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#                 Feature   Type Units Stage                     Description
# count                27     27    27    27                              27
# unique               27      3     7     5                              27
# top     received_snr_db  float    dB     B  Received signal-to-noise ratio
# freq                  1     23    14    10                               1

# %%
df.dtypes
# Out:
# Feature        object
# Type           object
# Units          object
# Stage          object
# Description    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Feature        0
# Type           0
# Units          0
# Stage          0
# Description    0
# dtype: int64

# %%
df.nunique()
# Out:
# Feature        27
# Type            3
# Units           7
# Stage           5
# Description    27
# dtype: int64

# %%
df.sample(5)
# Out:
#                    Feature    Type Units  Stage  \
# 22                   itu_k   float     —      C
# 6   gaseous_attenuation_db   float    dB      A
# 1    carrier_frequency_ghz   float   GHz  A/B/C
# 23               itu_alpha   float     —      C
# 25                 climate  string     —    B/C
#
#                                   Description
# 22   ITU-R specific attenuation coefficient k
# 6             Atmospheric gas absorption loss
# 1     Carrier frequency of the satellite link
# 23  ITU-R specific attenuation exponent alpha
# 25                Climate type classification

# %%
df.value_counts()
# Out:
# Feature                         Type      Units    Stage  Description
# attenuation_delta               float     dB       B      Difference in excess attenuation from previous step                           1
# attenuation_roll_mean           float     dB       B      Rolling excess attenuation mean over 5 minutes                                1
# attenuation_roll_std            float     dB       B      Rolling excess attenuation standard deviation over 5 minutes                  1
# carrier_frequency_ghz           float     GHz      A/B/C  Carrier frequency of the satellite link                                       1
# climate                         string    —        B/C    Climate type classification                                                   1
# effective_path_length_km        float     km       A      Effective path length through the rain layer                                  1
# ...
